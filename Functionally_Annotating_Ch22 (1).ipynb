# %% [markdown]
# # Merging Functional Annotations into the CADD Chr22 File using Python

# %% [markdown]
# Set Working Directory and Import Files / Pandas:

# %%
# Check Working Directory.

import os
import sys
print("wd"
     , os.getcwd())
# Out:
# wd /Users/patrickhallaert

# %%
# Set Working Directory to Hard Drive, which contains all the needed files.

os.chdir('/Volumes/HZU/CADD/hg19')
print("wd"
     , os.getcwd())
# Out:
# wd /Volumes/HZU/CADD/hg19

# %%
# Import Pandas and NumPy

import pandas as pd
import numpy as np

# %% [markdown]
# Import and View Chr22 CADD File

# %%
# We run the separator as ‘\t’ because in this file the tab character separates the fields.

ch22 = pd.read_csv("chr22F1-43m.txt",sep='\t', dtype = 'str')

# %%
# We can quickly view the data to make sure there are no issues and everything looks normal.

ch22.head()
# Out:
#                     ## CADD GRCh37-v1.6 (c) University of Washington, Hudson-Alpha Institute for Biotechnology and Berlin Institute of Health 2013-2019. All rights reserved.
# #Chrom Pos      Ref                                                Alt
# 22     16050001 G                                                    A
#                 G                                                    C
#                 G                                                    T
#        16050002 A                                                    C

# %%
print(ch22.columns.tolist())

# This first row will cause a KeyError as left_join will be unable to recognize the correct headers.
# Out:
# ['## CADD GRCh37-v1.6 (c) University of Washington, Hudson-Alpha Institute for Biotechnology and Berlin Institute of Health 2013-2019. All rights reserved.']

# %%
# Thus, we remove the "Title" Row (through the command line) to Prevent a future KeyError while Left_Joining CADD chr22 with a functional annotation dataset.

ch22nh = pd.read_csv("/Volumes/HZU/CADD/hg19/chr22F1-43mnh.txt",sep='\t', dtype = 'str')# iterator=True, chunksize=1000)

# %% [markdown]
# Import and View ClinVar Functional Annotations

# %%
# Now, we can import the ClinVar data.

clinvar = pd.read_csv('clinvar_20220528.txt', comment='#', sep='\t' , dtype='str')

# Additional bits (comment='#', sep='\t') needed to make the vcf file "readable" to Pandas left_join.

# %%
# Let's take a look:

clinvar.head()
# Out:
#    1  861332  1019397  G  A  . ..1  \
# 0  1  861336  1543320  C  T  .   .
# 1  1  861349  1648427  C  T  .   .
# 2  1  861356  1362713  T  C  .   .
# 3  1  861366  1568423  C  T  .   .
# 4  1  861383  1365270  C  T  .   .
#
#   ALLELEID=1003021;CLNDISDB=MedGen:CN517202;CLNDN=not_provided;CLNHGVS=NC_000001.10:g.861332G>A;CLNREVSTAT=criteria_provided,_single_submitter;CLNSIG=Uncertain_significance;CLNVC=single_nucleotide_variant;CLNVCSO=SO:0001483;GENEINFO=SAMD11:148398;MC=SO:0001583|missense_variant;ORIGIN=1;RS=1640863258
# 0  ALLELEID=1632777;CLNDISDB=MedGen:CN517202;CLND...
# 1  ALLELEID=1600580;CLNDISDB=MedGen:CN517202;CLND...
# 2  ALLELEID=1396033;CLNDISDB=MedGen:CN517202;CLND...
# 3  ALLELEID=1570515;CLNDISDB=MedGen:CN517202;CLND...
# 4  ALLELEID=1502313;CLNDISDB=MedGen:CN517202;CLND...

# %%
# Let's add headers.

clinvar.columns = ["#CHROM", "POS", "ID", "REF", "ALT", "QUAL", "FILTER", "INFO"]

# %%
# Let's take another look:

clinvar.head()
# Out:
#   #CHROM     POS       ID REF ALT QUAL FILTER  \
# 0      1  861336  1543320   C   T    .      .
# 1      1  861349  1648427   C   T    .      .
# 2      1  861356  1362713   T   C    .      .
# 3      1  861366  1568423   C   T    .      .
# 4      1  861383  1365270   C   T    .      .
#
#                                                 INFO
# 0  ALLELEID=1632777;CLNDISDB=MedGen:CN517202;CLND...
# 1  ALLELEID=1600580;CLNDISDB=MedGen:CN517202;CLND...
# 2  ALLELEID=1396033;CLNDISDB=MedGen:CN517202;CLND...
# 3  ALLELEID=1570515;CLNDISDB=MedGen:CN517202;CLND...
# 4  ALLELEID=1502313;CLNDISDB=MedGen:CN517202;CLND...

# %% [markdown]
# Import and View Eigen Functional Annotations

# %% [raw]
# After splicing from the original Eigen file, the Chr22 file no longer has headers corresponding to each column. Thus, we must reinsert them with Unix:
#
# $ echo -e "#chr\tposition\tposition\tref\talt\tSIFT\tPolyPhenDIV\tPolyPhenVar\tMA\tGERP_NR\tGERP_RS\tPhyloPri\tPhyloPla\tPhyloVer\tPhastPri\tPhastPla\tPhastVe\tConsequence\tEigen-raw\tEigen-phred\tEigen-PC-raw\tEigen-PC-phred" | cat - hg19_Eigen22.txt > everyheaders_hg19_Eigen22.txt

# %%
# Now, we repeat the process for the Eigen dataset.

eigen = pd.read_csv("/Volumes/HZU/everyheaders_hg19_Eigen22.txt",sep='\t', on_bad_lines='skip', dtype='str')
eigen.head()
# Out:
#   #chr  position position.1 ref alt SIFT PolyPhenDIV PolyPhenVar MA GERP_NR  \
# 0   22  16157306   16157306   T   A    .           .           .  .   0.511
# 1   22  16157306   16157306   T   C    .           .           .  .   0.511
# 2   22  16157306   16157306   T   G    .           .           .  .   0.511
# 3   22  16157307   16157307   C   A    .           .           .  .   0.511
# 4   22  16157307   16157307   C   G    .           .           .  .   0.511
#
#    ... PhyloPla PhyloVer PhastPri PhastPla PhastVe  \
# 0  ...    0.476    0.153    0.015    0.019   0.043
# 1  ...    0.476    0.153    0.015    0.019   0.043
# 2  ...    0.476    0.153    0.015    0.019   0.043
# 3  ...    0.569    0.680    0.016    0.022   0.049
# 4  ...    0.569    0.680    0.016    0.022   0.049
#
#                                     Consequence           Eigen-raw  \
# 0  intron_variant,non_coding_transcript_variant  -0.723507420492939
# 1  intron_variant,non_coding_transcript_variant  -0.723507420492939
# 2  intron_variant,non_coding_transcript_variant  -0.723507420492939
# 3  intron_variant,non_coding_transcript_variant  -0.690256467806581
# 4  intron_variant,non_coding_transcript_variant  -0.690256467806581
#
#   Eigen-phred        Eigen-PC-raw Eigen-PC-phred
# 0   0.7735336   -0.95435275448397      0.5475722
# 1   0.7735336   -0.95435275448397      0.5475722
# 2   0.7735336   -0.95435275448397      0.5475722
# 3    0.829126  -0.919775085203436      0.5935479
# 4    0.829126  -0.919775085203436      0.5935479
#
# [5 rows x 22 columns]

# %% [markdown]
# Import and View dbnsfp33a Functional Annotations

# %% [raw]
# To add headers we must once again use the Command Line:
#
# $ echo -e "#chr\tstart\tend\tref\talt\tSIFT_score\tSIFT_converted_rankscore\tSIFT_pred\tPolyphen2_HDIV_score\tPolyphen2_HDIV_rankscore\tPolyphen2_HDIV_pred\tPolyphen2_HVAR_score\tPolyphen2_HVAR_rankscore\tPolyphen2_HVAR_pred\tLRT_score\tLRT_converted_rankscore\tLRT_pred\tMutationTaster_score\tMutationTaster_converted_rankscore\tMutationTaster_pred\tMutationAssessor_score\tMutationAssessor_score_rankscore\tMutationAssessor_pred\tFATHMM_score\tFATHMM_converted_rankscore\tFATHMM_pred\tPROVEAN_score\tPROVEAN_converted_rankscore\tPROVEAN_pred\tVEST3_score\tVEST3_rankscore\tMetaSVM_score\tMetaSVM_rankscore\tMetaSVM_pred\tMetaLR_score\tMetaLR_rankscore\tMetaLR_pred\tM-CAP_score\tM-CAP_rankscore\tM-CAP_pred\tCADD_raw\tCADD_raw_rankscore\tCADD_phred\tDANN_score\tDANN_rankscore\tfathmm-MKL_coding_score\tfathmm-MKL_coding_rankscore\tfathmm-MKL_coding_pred\tEigen_coding_or_noncoding\tEigen-raw\tEigen-PC-raw\tGenoCanyon_score\tGenoCanyon_score_rankscore\tintegrated_fitCons_score\tintegrated_fitCons_score_rankscore\tintegrated_confidence_value\tGERP++_RS\tGERP++_RS_rankscore\tphyloP100way_vertebrate\tphyloP100way_vertebrate_rankscore\tphyloP20way_mammalian\tphyloP20way_mammalian_rankscore\tphastCons100way_vertebrate\tphastCons100way_vertebrate_rankscore\tphastCons20way_mammalian\tphastCons20way_mammalian_rankscore\tSiPhy_29way_logOdds\tSiPhy_29way_logOdds_rankscore\tInterpro_domain\tGTEx_V6_gene\tGTEx_V6_tissue" | cat - hg19_dbnsfp33a22.txt > everyheader_hg19_dbnsfp33a22.txt

# %%
# Finally, the dbnsfp33a annotations:
    
dbnsfp33a = pd.read_csv("/Volumes/HZU/humandb/everyheader_hg19_dbnsfp33a22.txt",sep='\t', on_bad_lines='skip' , dtype='str')
dbnsfp33a.head()
# Out:
#   #chr     start       end ref alt SIFT_score SIFT_converted_rankscore  \
# 0   22  16287549  16287549   G   A          .                        .
# 1   22  16287549  16287549   G   C          .                        .
# 2   22  16287549  16287549   G   T          .                        .
# 3   22  16287550  16287550   C   A          .                        .
# 4   22  16287550  16287550   C   G          .                        .
#
#   SIFT_pred Polyphen2_HDIV_score Polyphen2_HDIV_rankscore  ...  \
# 0         .                    .                        .  ...
# 1         .                    .                        .  ...
# 2         .                    .                        .  ...
# 3         .                    .                        .  ...
# 4         .                    .                        .  ...
#
#   phyloP20way_mammalian_rankscore phastCons100way_vertebrate  \
# 0                           0.247                      0.001
# 1                           0.247                      0.001
# 2                           0.247                      0.001
# 3                           0.001                      0.000
# 4                           0.001                      0.000
#
#   phastCons100way_vertebrate_rankscore phastCons20way_mammalian  \
# 0                                0.137                    0.000
# 1                                0.137                    0.000
# 2                                0.137                    0.000
# 3                                0.063                    0.000
# 4                                0.063                    0.000
#
#   phastCons20way_mammalian_rankscore SiPhy_29way_logOdds  \
# 0                              0.016                   .
# 1                              0.016                   .
# 2                              0.016                   .
# 3                              0.016                   .
# 4                              0.016                   .
#
#   SiPhy_29way_logOdds_rankscore Interpro_domain GTEx_V6_gene GTEx_V6_tissue
# 0                             .               .            .              .
# 1                             .               .            .              .
# 2                             .               .            .              .
# 3                             .               .            .              .
# 4                             .               .            .              .
#
# [5 rows x 71 columns]

# %% [markdown]
# Merge the CADD Ch22 File with Eigen First to create a "Ch22Eigen" File

# %%
ch22eigen = pd.merge(ch22nh, eigen, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'position', 'ref', 'alt'], how="left")
ch22eigen = ch22eigen.drop(columns="position.1")
ch22eigen = ch22eigen.drop(columns="ref")
ch22eigen = ch22eigen.drop(columns="alt")
ch22eigen = ch22eigen.drop(columns="position")
ch22eigen = ch22eigen.drop(columns="#chr")
ch22eigen
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... PhyloPla PhyloVer PhastPri PhastPla PhastVe Consequence  \
# 0           NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 1           NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 2           NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 3           NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 4           NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# ...         ...  ...      ...      ...      ...      ...     ...         ...
# 2999993     NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 2999994     NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 2999995     NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 2999996     NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
# 2999997     NaN  ...      NaN      NaN      NaN      NaN     NaN         NaN
#
#         Eigen-raw Eigen-phred Eigen-PC-raw Eigen-PC-phred
# 0             NaN         NaN          NaN            NaN
# 1             NaN         NaN          NaN            NaN
# 2             NaN         NaN          NaN            NaN
# 3             NaN         NaN          NaN            NaN
# 4             NaN         NaN          NaN            NaN
# ...           ...         ...          ...            ...
# 2999993       NaN         NaN          NaN            NaN
# 2999994       NaN         NaN          NaN            NaN
# 2999995       NaN         NaN          NaN            NaN
# 2999996       NaN         NaN          NaN            NaN
# 2999997       NaN         NaN          NaN            NaN
#
# [2999998 rows x 21 columns]

# %% [markdown]
# Now incorporate the dbnsfp33a data into this "Ch22Eigen" data:

# %%
ch22_eigen_dbn = pd.merge(ch22eigen, dbnsfp33a, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... phyloP20way_mammalian_rankscore  \
# 0           NaN  ...                             NaN
# 1           NaN  ...                             NaN
# 2           NaN  ...                             NaN
# 3           NaN  ...                             NaN
# 4           NaN  ...                             NaN
# ...         ...  ...                             ...
# 2999993     NaN  ...                             NaN
# 2999994     NaN  ...                             NaN
# 2999995     NaN  ...                             NaN
# 2999996     NaN  ...                             NaN
# 2999997     NaN  ...                             NaN
#
#         phastCons100way_vertebrate phastCons100way_vertebrate_rankscore  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
# ...                            ...                                  ...
# 2999993                        NaN                                  NaN
# 2999994                        NaN                                  NaN
# 2999995                        NaN                                  NaN
# 2999996                        NaN                                  NaN
# 2999997                        NaN                                  NaN
#
#         phastCons20way_mammalian phastCons20way_mammalian_rankscore  \
# 0                            NaN                                NaN
# 1                            NaN                                NaN
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                            NaN                                NaN
# ...                          ...                                ...
# 2999993                      NaN                                NaN
# 2999994                      NaN                                NaN
# 2999995                      NaN                                NaN
# 2999996                      NaN                                NaN
# 2999997                      NaN                                NaN
#
#         SiPhy_29way_logOdds SiPhy_29way_logOdds_rankscore Interpro_domain  \
# 0                       NaN                           NaN             NaN
# 1                       NaN                           NaN             NaN
# 2                       NaN                           NaN             NaN
# 3                       NaN                           NaN             NaN
# 4                       NaN                           NaN             NaN
# ...                     ...                           ...             ...
# 2999993                 NaN                           NaN             NaN
# 2999994                 NaN                           NaN             NaN
# 2999995                 NaN                           NaN             NaN
# 2999996                 NaN                           NaN             NaN
# 2999997                 NaN                           NaN             NaN
#
#         GTEx_V6_gene GTEx_V6_tissue
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 2999993          NaN            NaN
# 2999994          NaN            NaN
# 2999995          NaN            NaN
# 2999996          NaN            NaN
# 2999997          NaN            NaN
#
# [2999998 rows x 92 columns]

# %% [markdown]
# Merge in the ClinVar data to the file already containing CADD, Eigen, and dbnsfp33a data.

# %%
import gc
gc.collect()
# Out:
# 0

# %%
ch22_eigen_dbn_clinvar = pd.merge(ch22_eigen_dbn, clinvar, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#CHROM', 'POS', 'REF', 'ALT'], how="left")
ch22_eigen_dbn_clinvar
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="#CHROM")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="POS")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="ID")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="REF")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="ALT")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="QUAL")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="FILTER")
ch22_eigen_dbn_clinvar = ch22_eigen_dbn_clinvar.drop(columns="INFO")

# %% [raw]
# Splice the coding Fathmm file and isolate the chr22 section.
#
# In Command Line:
#
# $ gzip -k hg19_fathmm_xf_coding.txt
#
# $ gunzip -c hg19_fathmm_xf_coding.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_fathmm_xf_codingch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -

# %% [raw]
# Add headers in command line.
#
# $ echo -e "#Chrom\tPos\tposition\tRef\tAlt\tFATHMM_XF_coding" | cat - hg19_fathmm_xf_codingch22.txt > hg19_fathmm_xf_codingch22headers.txt

# %%
c_fathmm = pd.read_csv("/Volumes/HZU/humandb/hg19_fathmm_xf_codingch22headers.txt",sep='\t', dtype = 'str')
c_fathmm = c_fathmm.drop(columns="position")
c_fathmm
# Out:
#         #Chrom       Pos Ref Alt FATHMM_XF_coding
# 0           22  16258189   G   A         0.006646
# 1           22  16258189   G   C         0.066183
# 2           22  16258189   G   T         0.078170
# 3           22  16258190   A   C         0.039113
# 4           22  16258190   A   G         0.040414
# ...        ...       ...  ..  ..              ...
# 2232697     22  51220721   A   G         0.023020
# 2232698     22  51220721   A   T         0.034400
# 2232699     22  51220722   T   A         0.034870
# 2232700     22  51220722   T   C         0.033790
# 2232701     22  51220722   T   G         0.034870
#
# [2232702 rows x 5 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm = pd.merge(ch22_eigen_dbn_clinvar, c_fathmm, on =['#Chrom', 'Pos', 'Ref', 'Alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... phastCons100way_vertebrate  \
# 0           NaN  ...                        NaN
# 1           NaN  ...                        NaN
# 2           NaN  ...                        NaN
# 3           NaN  ...                        NaN
# 4           NaN  ...                        NaN
# ...         ...  ...                        ...
# 2999993     NaN  ...                        NaN
# 2999994     NaN  ...                        NaN
# 2999995     NaN  ...                        NaN
# 2999996     NaN  ...                        NaN
# 2999997     NaN  ...                        NaN
#
#         phastCons100way_vertebrate_rankscore phastCons20way_mammalian  \
# 0                                        NaN                      NaN
# 1                                        NaN                      NaN
# 2                                        NaN                      NaN
# 3                                        NaN                      NaN
# 4                                        NaN                      NaN
# ...                                      ...                      ...
# 2999993                                  NaN                      NaN
# 2999994                                  NaN                      NaN
# 2999995                                  NaN                      NaN
# 2999996                                  NaN                      NaN
# 2999997                                  NaN                      NaN
#
#         phastCons20way_mammalian_rankscore SiPhy_29way_logOdds  \
# 0                                      NaN                 NaN
# 1                                      NaN                 NaN
# 2                                      NaN                 NaN
# 3                                      NaN                 NaN
# 4                                      NaN                 NaN
# ...                                    ...                 ...
# 2999993                                NaN                 NaN
# 2999994                                NaN                 NaN
# 2999995                                NaN                 NaN
# 2999996                                NaN                 NaN
# 2999997                                NaN                 NaN
#
#         SiPhy_29way_logOdds_rankscore Interpro_domain GTEx_V6_gene  \
# 0                                 NaN             NaN          NaN
# 1                                 NaN             NaN          NaN
# 2                                 NaN             NaN          NaN
# 3                                 NaN             NaN          NaN
# 4                                 NaN             NaN          NaN
# ...                               ...             ...          ...
# 2999993                           NaN             NaN          NaN
# 2999994                           NaN             NaN          NaN
# 2999995                           NaN             NaN          NaN
# 2999996                           NaN             NaN          NaN
# 2999997                           NaN             NaN          NaN
#
#         GTEx_V6_tissue FATHMM_XF_coding
# 0                  NaN              NaN
# 1                  NaN              NaN
# 2                  NaN              NaN
# 3                  NaN              NaN
# 4                  NaN              NaN
# ...                ...              ...
# 2999993            NaN              NaN
# 2999994            NaN              NaN
# 2999995            NaN              NaN
# 2999996            NaN              NaN
# 2999997            NaN              NaN
#
# [2999998 rows x 93 columns]

# %% [raw]
# Splice the exome gnomad file and isolate the chr22 section.
#
# In Command Line:
#
# $ gzip -k hg19_gnomad211_exome.txt
#
# $ gunzip -c hg19_gnomad211_exome.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_gnomad211_exomechch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -
#
# $ $ echo -e "#chr\tstart\tend\tref\talt\tAF\tAF_popmax\tAF_male\tAF_female\tAF_raw\tAF_afr\tAF_sas\tAF_amr\tAF_eas\tAF_nfe\tAF_fin\tAF_asj\tAF_oth\tnon_topmed_AF_popmax\tnon_neuro_AF_popmax\tnon_cancer_AF_popmax\tcontrols_AF_popmax" | cat - hg19_gnomad211_exomechch22.txt > headers_hg19_gnomad211_exomech22.txt

# %%
exomegnomad = pd.read_csv("/Volumes/HZU/humandb/headers_hg19_gnomad211_exomech22.txt",sep='\t', dtype = 'str')
exomegnomad.head()
# Out:
#   #chr     start       end ref alt      AF AF_popmax AF_male AF_female  \
# 0   22  16157263  16157263   C   T  0.0054    0.0132  0.0043    0.0068
# 1   22  16157264  16157264   G   A  0.0703    0.1233  0.0721    0.0680
# 2   22  16157277  16157277   G   A  0.0014    0.0035  0.0019    0.0008
# 3   22  16157293  16157293   G   C  0.0014    0.0041  0.0017    0.0010
# 4   22  16157302  16157302   T   C       0         .       0         0
#
#       AF_raw  ...  AF_amr  AF_eas  AF_nfe  AF_fin AF_asj  AF_oth  \
# 0     0.0043  ...       0  0.0081       0       0      0  0.0294
# 1     0.0242  ...  0.1233       0  0.1042  0.0714      0  0.1154
# 2     0.0006  ...  0.0035  0.0026       0       0      0       0
# 3     0.0009  ...  0.0041       0  0.0008       0      0       0
# 4  2.028e-05  ...       0       0       0       0      0       0
#
#   non_topmed_AF_popmax non_neuro_AF_popmax non_cancer_AF_popmax  \
# 0               0.0132              0.0132               0.0132
# 1               0.1244              0.1293               0.1233
# 2               0.0035              0.0037               0.0035
# 3               0.0042              0.0045               0.0041
# 4                    .                   .                    .
#
#   controls_AF_popmax
# 0             0.0172
# 1             0.1272
# 2             0.0024
# 3             0.0031
# 4                  .
#
# [5 rows x 22 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad = pd.merge(ch22_eigen_dbn_clinvar_cfathmm, exomegnomad, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... AF_amr AF_eas AF_nfe AF_fin AF_asj AF_oth  \
# 0           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 1           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 3           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 4           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...  ...    ...    ...    ...    ...    ...    ...
# 2999993     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2999994     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2999995     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2999996     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2999997     NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
#         non_topmed_AF_popmax non_neuro_AF_popmax non_cancer_AF_popmax  \
# 0                        NaN                 NaN                  NaN
# 1                        NaN                 NaN                  NaN
# 2                        NaN                 NaN                  NaN
# 3                        NaN                 NaN                  NaN
# 4                        NaN                 NaN                  NaN
# ...                      ...                 ...                  ...
# 2999993                  NaN                 NaN                  NaN
# 2999994                  NaN                 NaN                  NaN
# 2999995                  NaN                 NaN                  NaN
# 2999996                  NaN                 NaN                  NaN
# 2999997                  NaN                 NaN                  NaN
#
#         controls_AF_popmax
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 2999993                NaN
# 2999994                NaN
# 2999995                NaN
# 2999996                NaN
# 2999997                NaN
#
# [2999998 rows x 115 columns]

# %% [markdown]
# Splice the non-coding Fathmm file and isolate the chr22 section.

# %%
gc.collect()
# Out:
# 0

# %% [raw]
# For hg19_abraom.txt
#
# gunzip -c hg19_abraom.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_abraom_ch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -

# %% [raw]
# echo -e "#chr\tstart\tend\tref\talt\tabraom_freq\tabraom_filter\tabraom_cegh_filter" | cat - hg19_abraom_ch22.txt > headers_hg19_abraom_ch22.txt

# %%
abraom = pd.read_csv("/Volumes/HZU/humandb/headers_hg19_abraom_ch22.txt",sep='\t', dtype = 'str')
abraom
# Out:
#       #chr     start       end ref alt abraom_freq  \
# 0       22  16256078  16256078   G   A    0.018072
# 1       22  16256352  16256352   T   C    0.404762
# 2       22  16256430  16256430   A   G    0.325581
# 3       22  16256484  16256484   T   C    0.078431
# 4       22  16256512  16256512   T   C    0.391081
# ...    ...       ...       ...  ..  ..         ...
# 60421   22  51237712  51237712   G   A    0.131250
# 60422   22  51237766  51237766   T   C    0.016393
# 60423   22  51238130  51238130   G   A    0.272727
# 60424   22  51238249  51238249   A   C    0.063492
# 60425   22  51238368  51238368   C   T    0.120968
#
#                      abraom_filter abraom_cegh_filter
# 0                          LowQual                FAB
# 1      VQSRTrancheSNP99.90to100.00         WK-LowCall
# 2      VQSRTrancheSNP99.90to100.00         WK-LowCall
# 3      VQSRTrancheSNP99.90to100.00                FAB
# 4       VQSRTrancheSNP99.00to99.90         WK-LowCall
# ...                            ...                ...
# 60421   VQSRTrancheSNP99.00to99.90                FAB
# 60422   VQSRTrancheSNP99.00to99.90                FAB
# 60423   VQSRTrancheSNP99.00to99.90                FDP
# 60424   VQSRTrancheSNP99.00to99.90                FDP
# 60425   VQSRTrancheSNP99.00to99.90                FDP
#
# [60426 rows x 8 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = pd.merge(ch22_eigen_dbn_clinvar_cfathmm_exomegnomad, abraom, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... non_cancer_AF_popmax controls_AF_popmax #chr start  end  \
# 0           NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 1           NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 2           NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 3           NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 4           NaN  ...                  NaN                NaN  NaN   NaN  NaN
# ...         ...  ...                  ...                ...  ...   ...  ...
# 2999993     NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 2999994     NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 2999995     NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 2999996     NaN  ...                  NaN                NaN  NaN   NaN  NaN
# 2999997     NaN  ...                  NaN                NaN  NaN   NaN  NaN
#
#          ref  alt abraom_freq abraom_filter abraom_cegh_filter
# 0        NaN  NaN         NaN           NaN                NaN
# 1        NaN  NaN         NaN           NaN                NaN
# 2        NaN  NaN         NaN           NaN                NaN
# 3        NaN  NaN         NaN           NaN                NaN
# 4        NaN  NaN         NaN           NaN                NaN
# ...      ...  ...         ...           ...                ...
# 2999993  NaN  NaN         NaN           NaN                NaN
# 2999994  NaN  NaN         NaN           NaN                NaN
# 2999995  NaN  NaN         NaN           NaN                NaN
# 2999996  NaN  NaN         NaN           NaN                NaN
# 2999997  NaN  NaN         NaN           NaN                NaN
#
# [2999998 rows x 123 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="alt_x")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="start_x")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="ref_x")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="#chr")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="alt")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="start")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="ref")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom.drop(columns="#chr_x")

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... AF_asj AF_oth non_topmed_AF_popmax non_neuro_AF_popmax  \
# 0           NaN  ...    NaN    NaN                  NaN                 NaN
# 1           NaN  ...    NaN    NaN                  NaN                 NaN
# 2           NaN  ...    NaN    NaN                  NaN                 NaN
# 3           NaN  ...    NaN    NaN                  NaN                 NaN
# 4           NaN  ...    NaN    NaN                  NaN                 NaN
# ...         ...  ...    ...    ...                  ...                 ...
# 2999993     NaN  ...    NaN    NaN                  NaN                 NaN
# 2999994     NaN  ...    NaN    NaN                  NaN                 NaN
# 2999995     NaN  ...    NaN    NaN                  NaN                 NaN
# 2999996     NaN  ...    NaN    NaN                  NaN                 NaN
# 2999997     NaN  ...    NaN    NaN                  NaN                 NaN
#
#         non_cancer_AF_popmax controls_AF_popmax  end abraom_freq  \
# 0                        NaN                NaN  NaN         NaN
# 1                        NaN                NaN  NaN         NaN
# 2                        NaN                NaN  NaN         NaN
# 3                        NaN                NaN  NaN         NaN
# 4                        NaN                NaN  NaN         NaN
# ...                      ...                ...  ...         ...
# 2999993                  NaN                NaN  NaN         NaN
# 2999994                  NaN                NaN  NaN         NaN
# 2999995                  NaN                NaN  NaN         NaN
# 2999996                  NaN                NaN  NaN         NaN
# 2999997                  NaN                NaN  NaN         NaN
#
#         abraom_filter abraom_cegh_filter
# 0                 NaN                NaN
# 1                 NaN                NaN
# 2                 NaN                NaN
# 3                 NaN                NaN
# 4                 NaN                NaN
# ...               ...                ...
# 2999993           NaN                NaN
# 2999994           NaN                NaN
# 2999995           NaN                NaN
# 2999996           NaN                NaN
# 2999997           NaN                NaN
#
# [2999998 rows x 115 columns]

# %% [raw]
# # In command line:
#
# gzip -k hg19_AFR.sites.2015_08.txt
# gunzip -c hg19_AFR.sites.2015_08.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_AFR.sites.2015_08_ch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -
#
# gzip -k hg19_ALL.sites.2015_08.txt
# gunzip -c hg19_ALL.sites.2015_08.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_ALL.sites.2015_08.txt_ch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -
#
# gzip -k hg19_AMR.sites.2015_08.txt
# gunzip -c hg19_AMR.sites.2015_08.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_AMR.sites.2015_08_ch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -
#
# gzip -k hg19_EAS.sites.2015_08.txt
# gunzip -c hg19_EAS.sites.2015_08.txt.gz | gawk 'BEGIN{Ch=""}{if($1~"#"){H[FNR]=$0;nh++}else{if($1!=Ch){Ch=$1;Out="hg19_EAS.sites.2015_08_ch"$1".txt";for(i=1;i<=nh;i++){printH[i] >Out}}; print $0 > Out}}' -

# %%
gc.collect()
AFR = pd.read_csv('/Volumes/HZU/humandb/hg19_AFR.sites.2015_08_ch22.txt', comment='#', sep='\t' , dtype='str')
ALL = pd.read_csv('/Volumes/HZU/humandb/hg19_ALL.sites.2015_08_ch22.txt', comment='#', sep='\t' , dtype='str')
AMR = pd.read_csv('/Volumes/HZU/humandb/hg19_AMR.sites.2015_08_ch22.txt', comment='#', sep='\t' , dtype='str')
AMR = pd.read_csv('/Volumes/HZU/humandb/hg19_AMR.sites.2015_08_ch22.txt', comment='#', sep='\t' , dtype='str')
EAS = pd.read_csv('/Volumes/HZU/humandb/hg19_EAS.sites.2015_08_ch22.txt', comment='#', sep='\t' , dtype='str')
AFR.columns = ["#chr", "start", "ref", "alt", "AFR_exome_allele_frequency", "rsID"]
ALL.columns = ["#chr", "start", "ref", "alt", "ALL_exome_allele_frequency", "rsID"]
AMR.columns = ["#chr", "start", "ref", "alt", "AMR_exome_allele_frequency", "rsID"]
EAS.columns = ["#chr", "start", "ref", "alt", "EAS_exome_allele_frequency", "rsID"]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = pd.merge(ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom, ALL, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ...  end abraom_freq abraom_filter abraom_cegh_filter #chr  \
# 0           NaN  ...  NaN         NaN           NaN                NaN  NaN
# 1           NaN  ...  NaN         NaN           NaN                NaN  NaN
# 2           NaN  ...  NaN         NaN           NaN                NaN  NaN
# 3           NaN  ...  NaN         NaN           NaN                NaN  NaN
# 4           NaN  ...  NaN         NaN           NaN                NaN  NaN
# ...         ...  ...  ...         ...           ...                ...  ...
# 2999993     NaN  ...  NaN         NaN           NaN                NaN  NaN
# 2999994     NaN  ...  NaN         NaN           NaN                NaN  NaN
# 2999995     NaN  ...  NaN         NaN           NaN                NaN  NaN
# 2999996     NaN  ...  NaN         NaN           NaN                NaN  NaN
# 2999997     NaN  ...  NaN         NaN           NaN                NaN  NaN
#
#         start  ref  alt ALL_exome_allele_frequency rsID
# 0         NaN  NaN  NaN                        NaN  NaN
# 1         NaN  NaN  NaN                        NaN  NaN
# 2         NaN  NaN  NaN                        NaN  NaN
# 3         NaN  NaN  NaN                        NaN  NaN
# 4         NaN  NaN  NaN                        NaN  NaN
# ...       ...  ...  ...                        ...  ...
# 2999993   NaN  NaN  NaN                        NaN  NaN
# 2999994   NaN  NaN  NaN                        NaN  NaN
# 2999995   NaN  NaN  NaN                        NaN  NaN
# 2999996   NaN  NaN  NaN                        NaN  NaN
# 2999997   NaN  NaN  NaN                        NaN  NaN
#
# [2999998 rows x 121 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL.drop(columns="#chr")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL.drop(columns="alt")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL.drop(columns="start")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL.drop(columns="ref")

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL.drop(columns="rsID")

# %%
gc.collect()
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR = pd.merge(ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL, AFR, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... abraom_freq abraom_filter abraom_cegh_filter  \
# 0           NaN  ...         NaN           NaN                NaN
# 1           NaN  ...         NaN           NaN                NaN
# 2           NaN  ...         NaN           NaN                NaN
# 3           NaN  ...         NaN           NaN                NaN
# 4           NaN  ...         NaN           NaN                NaN
# ...         ...  ...         ...           ...                ...
# 2999993     NaN  ...         NaN           NaN                NaN
# 2999994     NaN  ...         NaN           NaN                NaN
# 2999995     NaN  ...         NaN           NaN                NaN
# 2999996     NaN  ...         NaN           NaN                NaN
# 2999997     NaN  ...         NaN           NaN                NaN
#
#         ALL_exome_allele_frequency #chr start  ref  alt  \
# 0                              NaN  NaN   NaN  NaN  NaN
# 1                              NaN  NaN   NaN  NaN  NaN
# 2                              NaN  NaN   NaN  NaN  NaN
# 3                              NaN  NaN   NaN  NaN  NaN
# 4                              NaN  NaN   NaN  NaN  NaN
# ...                            ...  ...   ...  ...  ...
# 2999993                        NaN  NaN   NaN  NaN  NaN
# 2999994                        NaN  NaN   NaN  NaN  NaN
# 2999995                        NaN  NaN   NaN  NaN  NaN
# 2999996                        NaN  NaN   NaN  NaN  NaN
# 2999997                        NaN  NaN   NaN  NaN  NaN
#
#         AFR_exome_allele_frequency rsID
# 0                              NaN  NaN
# 1                              NaN  NaN
# 2                              NaN  NaN
# 3                              NaN  NaN
# 4                              NaN  NaN
# ...                            ...  ...
# 2999993                        NaN  NaN
# 2999994                        NaN  NaN
# 2999995                        NaN  NaN
# 2999996                        NaN  NaN
# 2999997                        NaN  NaN
#
# [2999998 rows x 122 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR.drop(columns=['#chr', "start", "ref", "alt", "rsID"])
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... non_topmed_AF_popmax non_neuro_AF_popmax  \
# 0           NaN  ...                  NaN                 NaN
# 1           NaN  ...                  NaN                 NaN
# 2           NaN  ...                  NaN                 NaN
# 3           NaN  ...                  NaN                 NaN
# 4           NaN  ...                  NaN                 NaN
# ...         ...  ...                  ...                 ...
# 2999993     NaN  ...                  NaN                 NaN
# 2999994     NaN  ...                  NaN                 NaN
# 2999995     NaN  ...                  NaN                 NaN
# 2999996     NaN  ...                  NaN                 NaN
# 2999997     NaN  ...                  NaN                 NaN
#
#         non_cancer_AF_popmax controls_AF_popmax  end abraom_freq  \
# 0                        NaN                NaN  NaN         NaN
# 1                        NaN                NaN  NaN         NaN
# 2                        NaN                NaN  NaN         NaN
# 3                        NaN                NaN  NaN         NaN
# 4                        NaN                NaN  NaN         NaN
# ...                      ...                ...  ...         ...
# 2999993                  NaN                NaN  NaN         NaN
# 2999994                  NaN                NaN  NaN         NaN
# 2999995                  NaN                NaN  NaN         NaN
# 2999996                  NaN                NaN  NaN         NaN
# 2999997                  NaN                NaN  NaN         NaN
#
#         abraom_filter abraom_cegh_filter ALL_exome_allele_frequency  \
# 0                 NaN                NaN                        NaN
# 1                 NaN                NaN                        NaN
# 2                 NaN                NaN                        NaN
# 3                 NaN                NaN                        NaN
# 4                 NaN                NaN                        NaN
# ...               ...                ...                        ...
# 2999993           NaN                NaN                        NaN
# 2999994           NaN                NaN                        NaN
# 2999995           NaN                NaN                        NaN
# 2999996           NaN                NaN                        NaN
# 2999997           NaN                NaN                        NaN
#
#         AFR_exome_allele_frequency
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 2999993                        NaN
# 2999994                        NaN
# 2999995                        NaN
# 2999996                        NaN
# 2999997                        NaN
#
# [2999998 rows x 117 columns]

# %%
gc.collect()
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS = pd.merge(ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR, EAS, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... abraom_filter abraom_cegh_filter  \
# 0           NaN  ...           NaN                NaN
# 1           NaN  ...           NaN                NaN
# 2           NaN  ...           NaN                NaN
# 3           NaN  ...           NaN                NaN
# 4           NaN  ...           NaN                NaN
# ...         ...  ...           ...                ...
# 2999993     NaN  ...           NaN                NaN
# 2999994     NaN  ...           NaN                NaN
# 2999995     NaN  ...           NaN                NaN
# 2999996     NaN  ...           NaN                NaN
# 2999997     NaN  ...           NaN                NaN
#
#         ALL_exome_allele_frequency AFR_exome_allele_frequency #chr start  ref  \
# 0                              NaN                        NaN  NaN   NaN  NaN
# 1                              NaN                        NaN  NaN   NaN  NaN
# 2                              NaN                        NaN  NaN   NaN  NaN
# 3                              NaN                        NaN  NaN   NaN  NaN
# 4                              NaN                        NaN  NaN   NaN  NaN
# ...                            ...                        ...  ...   ...  ...
# 2999993                        NaN                        NaN  NaN   NaN  NaN
# 2999994                        NaN                        NaN  NaN   NaN  NaN
# 2999995                        NaN                        NaN  NaN   NaN  NaN
# 2999996                        NaN                        NaN  NaN   NaN  NaN
# 2999997                        NaN                        NaN  NaN   NaN  NaN
#
#          alt EAS_exome_allele_frequency rsID
# 0        NaN                        NaN  NaN
# 1        NaN                        NaN  NaN
# 2        NaN                        NaN  NaN
# 3        NaN                        NaN  NaN
# 4        NaN                        NaN  NaN
# ...      ...                        ...  ...
# 2999993  NaN                        NaN  NaN
# 2999994  NaN                        NaN  NaN
# 2999995  NaN                        NaN  NaN
# 2999996  NaN                        NaN  NaN
# 2999997  NaN                        NaN  NaN
#
# [2999998 rows x 123 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS.drop(columns=['#chr', "start", "ref", "alt", "rsID"])
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... non_neuro_AF_popmax non_cancer_AF_popmax  \
# 0           NaN  ...                 NaN                  NaN
# 1           NaN  ...                 NaN                  NaN
# 2           NaN  ...                 NaN                  NaN
# 3           NaN  ...                 NaN                  NaN
# 4           NaN  ...                 NaN                  NaN
# ...         ...  ...                 ...                  ...
# 2999993     NaN  ...                 NaN                  NaN
# 2999994     NaN  ...                 NaN                  NaN
# 2999995     NaN  ...                 NaN                  NaN
# 2999996     NaN  ...                 NaN                  NaN
# 2999997     NaN  ...                 NaN                  NaN
#
#         controls_AF_popmax  end abraom_freq abraom_filter abraom_cegh_filter  \
# 0                      NaN  NaN         NaN           NaN                NaN
# 1                      NaN  NaN         NaN           NaN                NaN
# 2                      NaN  NaN         NaN           NaN                NaN
# 3                      NaN  NaN         NaN           NaN                NaN
# 4                      NaN  NaN         NaN           NaN                NaN
# ...                    ...  ...         ...           ...                ...
# 2999993                NaN  NaN         NaN           NaN                NaN
# 2999994                NaN  NaN         NaN           NaN                NaN
# 2999995                NaN  NaN         NaN           NaN                NaN
# 2999996                NaN  NaN         NaN           NaN                NaN
# 2999997                NaN  NaN         NaN           NaN                NaN
#
#         ALL_exome_allele_frequency AFR_exome_allele_frequency  \
# 0                              NaN                        NaN
# 1                              NaN                        NaN
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                              NaN                        NaN
# ...                            ...                        ...
# 2999993                        NaN                        NaN
# 2999994                        NaN                        NaN
# 2999995                        NaN                        NaN
# 2999996                        NaN                        NaN
# 2999997                        NaN                        NaN
#
#         EAS_exome_allele_frequency
# 0                              NaN
# 1                              NaN
# 2                              NaN
# 3                              NaN
# 4                              NaN
# ...                            ...
# 2999993                        NaN
# 2999994                        NaN
# 2999995                        NaN
# 2999996                        NaN
# 2999997                        NaN
#
# [2999998 rows x 118 columns]

# %%
gc.collect()
# Out:
# 0

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS_AMR = pd.merge(ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS, AMR, left_on=['#Chrom', 'Pos', 'Ref', 'Alt'], right_on=['#chr', 'start', 'ref', 'alt'], how="left")

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS_AMR
# Out:
#         #Chrom       Pos Ref Alt SIFT PolyPhenDIV PolyPhenVar   MA GERP_NR  \
# 0           22  16050001   G   A  NaN         NaN         NaN  NaN     NaN
# 1           22  16050001   G   C  NaN         NaN         NaN  NaN     NaN
# 2           22  16050001   G   T  NaN         NaN         NaN  NaN     NaN
# 3           22  16050002   A   C  NaN         NaN         NaN  NaN     NaN
# 4           22  16050002   A   G  NaN         NaN         NaN  NaN     NaN
# ...        ...       ...  ..  ..  ...         ...         ...  ...     ...
# 2999993     22  16929617   A   T  NaN         NaN         NaN  NaN     NaN
# 2999994     22  16929618   T   A  NaN         NaN         NaN  NaN     NaN
# 2999995     22  16929618   T   C  NaN         NaN         NaN  NaN     NaN
# 2999996     22  16929618   T   G  NaN         NaN         NaN  NaN     NaN
# 2999997     22  16929619   A   C  NaN         NaN         NaN  NaN     NaN
#
#         GERP_RS  ... abraom_cegh_filter ALL_exome_allele_frequency  \
# 0           NaN  ...                NaN                        NaN
# 1           NaN  ...                NaN                        NaN
# 2           NaN  ...                NaN                        NaN
# 3           NaN  ...                NaN                        NaN
# 4           NaN  ...                NaN                        NaN
# ...         ...  ...                ...                        ...
# 2999993     NaN  ...                NaN                        NaN
# 2999994     NaN  ...                NaN                        NaN
# 2999995     NaN  ...                NaN                        NaN
# 2999996     NaN  ...                NaN                        NaN
# 2999997     NaN  ...                NaN                        NaN
#
#         AFR_exome_allele_frequency EAS_exome_allele_frequency #chr start  ref  \
# 0                              NaN                        NaN  NaN   NaN  NaN
# 1                              NaN                        NaN  NaN   NaN  NaN
# 2                              NaN                        NaN  NaN   NaN  NaN
# 3                              NaN                        NaN  NaN   NaN  NaN
# 4                              NaN                        NaN  NaN   NaN  NaN
# ...                            ...                        ...  ...   ...  ...
# 2999993                        NaN                        NaN  NaN   NaN  NaN
# 2999994                        NaN                        NaN  NaN   NaN  NaN
# 2999995                        NaN                        NaN  NaN   NaN  NaN
# 2999996                        NaN                        NaN  NaN   NaN  NaN
# 2999997                        NaN                        NaN  NaN   NaN  NaN
#
#          alt AMR_exome_allele_frequency rsID
# 0        NaN                        NaN  NaN
# 1        NaN                        NaN  NaN
# 2        NaN                        NaN  NaN
# 3        NaN                        NaN  NaN
# 4        NaN                        NaN  NaN
# ...      ...                        ...  ...
# 2999993  NaN                        NaN  NaN
# 2999994  NaN                        NaN  NaN
# 2999995  NaN                        NaN  NaN
# 2999996  NaN                        NaN  NaN
# 2999997  NaN                        NaN  NaN
#
# [2999998 rows x 124 columns]

# %%
ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS_AMR = ch22_eigen_dbn_clinvar_cfathmm_exomegnomad_abraom_ALL_AFR_EAS_AMR.drop(columns=['#chr', "start", "ref", "alt", "rsID"])
